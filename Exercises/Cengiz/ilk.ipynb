# %%
# Python Genel Tanıtım
* Variables
* Control Structures
* Functions
* Modul and Packages
## Variables
var1 = 2 # int
var2 = 2.2 # float
var3 = 2.3 + 4j # complex
########### 
var4 = "Digital Akademi" # str
var5 = [1,2,3,4,] # list
var6 = (1,2,3,4) # tuple
# var4[0]
#       0 1 2 3 
###############
var7 = {"Adı":"Digital"} # dict
# var7["Adı"]
var8 = {1,2,3,4} # set
var9 = True
###############

print(type(var1))
# var5.https://ibrahimediz-introductio-668ltuusdes.ws-us103.gitpod.io/


## Control Structures
* Loops
* Conditional Structures
### Loops
* for
* while
#### for
for i in range(1,10,2):
    print(i)
liste = [1,2,3,4,5]
for item in liste:
    print(item)
#### while
a = 1
while a < 5:
    a += 1
print(a)
for i in range(5):
    print(i)
else:
    print("Bitti")
* break
* continue
for i in range(5):
    if i == 2:
        break
    print(i)
else:
    print("Bitti")
for i in range(5):
    if i == 2:
        continue
    print(i)
else:
    print("Bitti")
### Conditional Structure
var1 = 1
var2 = ""
var3 = []
if var1:
    print("Dolu")
else:
    print("Boş")
yasi = input("Yaşınızı Giriniz:")
if yasi and yasi.isdigit():
    yasi = int(yasi)
    print(f"Yaşı {yasi}")
else:
    print("Giriş Yapmalısınız")

# _not = 65
# if 85 < _not < 100:
#     print("AA")
# elif 70<_not<85:
#         print("BB")

## Functions
# Don't Repeat Yourself  DRY
# We Enjoy Texting WET

a = 1
b = 1
c = a+b
print(c)
a = b 
b = c
c = a+b
print(c)
a = b 
b = c
c = a+b
print(c)
a = b 
b = c
c = a+b
print(c)
a = b 
b = c
c = a+b
print(c)
a = b 
b = c
c = a+b
print(c)
a = b = 1
a,b = b,a+b
print(a+b)
a,b = b,a+b
print(a+b)
a,b = b,a+b
print(a+b)
a,b = b,a+b
print(a+b)
a,b = b,a+b
print(a+b)
a,b = b,a+b
print(a+b)

a = b = 1
for i in range(20):
    a,b = b,a+b
    print(a+b)
def fibo(terim):
    a = b = 1
    for i in range(terim):
        a,b = b,a+b
        print(a+b)
fibo(10)
fibo(30)
def fibo(terim,param=1):
    a = b = 1
    for i in range(terim):
        a,b = b,a+b
        if param:
            print(a+b)
    else:
        if not param:
            print(a+b)
fibo(10,0)
def fonk(a,b,*args,**kwargs):
    print(a,b)
    print(args)
    print(kwargs)
fonk(1,2,3,4,5,6,7,selam="Merhaba")
fonk.__name__
## Module and Packages
* from 
* import 
from os import path
path.exists("deneme")
import os
os.path.exists("deneme")
import matplotlib.pyplot as plt
plt.figure()
from sklearn.model_selection import train_test_split as tts,cross_val_score as cvs
import sys
sys.path
# %pip install numpy
